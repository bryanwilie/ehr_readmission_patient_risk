# %% [markdown]
# ## Reproducing LePendu et al
#
# Annotates clinical text from EHR systems -> __extract disease and drug mentions from the EHR.__<br>
#
# Re-read the paper again!
#
# ### More to do
# - Obtaining ICD9 discharge codes<br>
# Patient visits include in some cases the discharge diagnosis in the form of an ICD9 code. <br>
# The ICD9 codes for rheumatoid arthritis begin with 714 and the ICD9 code for myocardial infarction begins with 410. <br>
# We __include these manually encoded terms as part of the analysis__ as a __comparison against what we can find in the text itself__.
# - We are also extending the system to discern additional contextual cues such as family history versus recent diagnosis.
#
# ### More details
# - More terminologies [UMLS Metathesaurus Vocabulary Documentation](nlm.nih.gov/research/umls/sourcereleasedocs/index.html), [VSAC Downloadable Resources](https://vsac.nlm.nih.gov/download/ccda?rel=20210810), [CDE](https://cde.nlm.nih.gov/home)<br>
# - Some guide on querying: [How to extract/get all the terms(classes/properties) in an ontology](https://stackoverflow.com/questions/52655960/how-to-extract-get-all-the-termsclasses-properties-in-an-ontology), [querying the owl ontology](https://stackoverflow.com/questions/22542348/querying-the-owl-ontology), [SPARQL query](https://owlready2.readthedocs.io/en/v0.35/sparql.html)
#
# ### HADCL Goals
#
# - Analyze the trade-off of applying traditional approach with recent sequence modeling approach for modeling EHR data
# - Benchmarking different pretrained language models for understanding EHR data
# - Exploring the use of EHR data allocation estimation in Hong Kong population
#     - Unplanned readmission
#     - Mortality risk
#     - Disease diagnosis
#     - Length of stay
#
# ## 1. Initialize

# %%
import pandas as pd
pd.set_option('display.max_colwidth', 100) 

from terminology import obtain_lexicons
from annotate import get_patients_annotated_terms
from helper import temporally_ordered_list_join
from normalizer import get_rxnorm_normalizer

path = 'data_pool/'
# Out:
# * Owlready2 * Warning: optimized Cython parser module 'owlready2_optimized' is not available, defaulting to slower Python implementation

# %%
# sample_clinical_text = "This is a 31 year old male s/p seizure on ladder with resulting fall 15-20 feet on [**09-17**] now presenting to the T/SICU post surgical repair of multiple facial fractures, open reduction of mandibular fracture, right mandibular fracture, and left distal radius fracture. He needs to remain intubated for 48 hours post-op. His past medical history is significant only for seizure disorder, and his only medication is depakote. He has no known allergies."
                        # (the "Open reduction of mandibular fracture" is fabricated)

# mimic_iii_demo = path + 'mimic-iii-clinical-database-demo-1.4/'
# df = pd.read_csv(mimic_iii_demo + 'D_ICD_DIAGNOSES.csv')
# print('df.iloc[0][\'long_title\']', df.iloc[0]['long_title'])
# df.head(3)

# %%
df = pd.read_csv('./negex/python/Annotations-1-120.txt', delimiter='\t')
df.head()
# Out:
#    Report No.              Concept  \
# 0           1  shortness of breath
# 1           1   staph   bacteremia
# 2           1            infection
# 3           1            infection
# 4           1            infection
#
#                                                                                               Sentence  \
# 0  S_O_H  Counters Report Type Record Type Subgroup Classifier  1,01TdvtyYejbW DS DS 1504  E_O_H  [...
# 1  S_O_H  Counters Report Type Record Type Subgroup Classifier  1,01TdvtyYejbW DS DS 1504  E_O_H  [...
# 2  The patient was transferred to **INSTITUTION for   explantation of a pacemaker system that was f...
# 3  The patient was sent back to **INSTITUTION the   following day for further evaluation and manage...
# 4  It was   planned to follow up in the **INSTITUTION for reimplantation of the   pacemaker once th...
#
#    Negation
# 0  Affirmed
# 1  Affirmed
# 2  Affirmed
# 3  Affirmed
# 4  Affirmed

# %%
df.shape
# Out:
# (2376, 4)

# %% [markdown]
# ## 2. Obtaining terminologies
#
# Obtained are UMLS terminologies: SNOMEDCT_US; RXNORM; NDFRT, and Human Disease Ontology<br>
# Ontologies are downloaded from [UMLS](https://www.nlm.nih.gov/research/umls/licensedcontent/umlsknowledgesources.html) and [OLS Ontology Search](https://www.ebi.ac.uk/ols/ontologies/doid) (umls-2021AB-full.zip), using ([Owlready2](https://pypi.org/project/Owlready2/) | [Source](https://bitbucket.org/jibalamy/owlready2/src/master/doc/))<br>
#
# __TODO__:
# 1. Need to also include __manually encoded ICD9 terms__ for each patient encounter as additional terms
# 2. Combine with coded and structured data when possible
# 3. The resulting lexicon contains __2.8 million unique terms.__, gathered are only 550k

# %%
# %%time

unique_terms = obtain_lexicons()
# Out:
# Importing UMLS from umls-2021AB-full.zip with Python version 3.8.8 and Owlready version 2-0.35...
# Full UMLS release - importing UMLS from inner Zip file 2021AB-full/2021ab-1-meta.nlm...
#   Parsing 2021AB/META/MRRANK.RRF.gz as MRRANK with encoding UTF-8
#   Parsing 2021AB/META/MRCONSO.RRF.aa.gz as MRCONSO with encoding UTF-8
#   Parsing 2021AB/META/MRCONSO.RRF.ab.gz as MRCONSO with encoding UTF-8
#   Parsing 2021AB/META/MRDEF.RRF.gz as MRDEF with encoding UTF-8
# Full UMLS release - importing UMLS from inner Zip file 2021AB-full/2021ab-2-meta.nlm...
#   Parsing 2021AB/META/MRREL.RRF.aa.gz as MRREL with encoding UTF-8
#   Parsing 2021AB/META/MRREL.RRF.ab.gz as MRREL with encoding UTF-8
#   Parsing 2021AB/META/MRREL.RRF.ac.gz as MRREL with encoding UTF-8
#   Parsing 2021AB/META/MRREL.RRF.ad.gz as MRREL with encoding UTF-8
#   Parsing 2021AB/META/MRSAT.RRF.aa.gz as MRSAT with encoding UTF-8
#   Parsing 2021AB/META/MRSAT.RRF.ab.gz as MRSAT with encoding UTF-8
#   Parsing 2021AB/META/MRSAT.RRF.ac.gz as MRSAT with encoding UTF-8
#   Parsing 2021AB/META/MRSAT.RRF.ad.gz as MRSAT with encoding UTF-8
#   Parsing 2021AB/META/MRSAT.RRF.ae.gz as MRSAT with encoding UTF-8
#   Parsing 2021AB/META/MRSAT.RRF.af.gz as MRSAT with encoding UTF-8
# Breaking ORIG cycles...
#     RXNORM : 0 cycles found:
#     SNOMEDCT_US : 0 cycles found:
#     SRC : 0 cycles found:
# Finalizing only properties and restrictions...
# Finalizing CUI - ORIG mapping...
# FTS Indexing...
# Obtaining Human Disease Ontology
# <timed exec>:1: DtypeWarning: Columns (8,52,66,72,79) have mixed types.Specify dtype option on import or set low_memory=False.
# /home/bryan/ehr_readmission_patient_risk/helper.py:17: FutureWarning: The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead
#   return pd.np.nan
# /home/bryan/ehr_readmission_patient_risk/helper.py:9: FutureWarning: The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead
#   return pd.np.nan
# Obtaining Negex samples' Concept
# 478914 unique terms obtained
# CPU times: user 9min 8s, sys: 7.01 s, total: 9min 15s
# Wall time: 9min 15s

# %%
for unique_term in unique_terms:
    if len(unique_term) < 5:
        print(unique_term)
# Out:
# GB9
# Pi
# LR2
# BL55
# acre
# 3.75
# 555
# Chi
# 1.24
# Dry
# MI
# KI10
# Bee
# mol
# Psi
# 625
# Out
# 10.8
# mm/h
# U/mg
# CHF
# Does
# Avar
# s
# face
# 1011
# Vine
# w
# 1432
# Zinc
# PVC
# 840
# RGA
# LU2
# 8G
# Ammi
# PUL
# 1.25
# 290
# 3.7
# Foam
# kPa
# 179
# ns
# 7.5
# Pus
# Qwo
# 6.6
# 2
# 26
# Herb
# 15
# CV23
# 30mm
# 28.6
# Hot
# V
# Hz
# HEP
# 4.56
# 1A
# Taro
# Rum
# 3/24
# Pack
# 11.6
# 6712
# volt
# g/L
# 1295
# pint
# 12.6
# Dike
# In
# A
# ft
# 3.1
# Dirk
# Door
# 66
# If
# Muse
# 72
# >97
# 450
# BL7
# D
# T
# 50
# 0.46
# BL17
# bran
# 500
# Fan
# 720
# ST40
# J12
# 4.8
# tube
# P1.9
# Luis
# 22.5
# Gin
# Onge
# pain
# Hemi
# LI15
# Hoya
# Ibu
# 3400
# Bulb
# TE5
# 0.42
# GB2
# 1.05
# Soil
# Sium
# 3705
# kat
# GB17
# CV18
# 0.04
# mm/s
# 313
# SP16
# Inzo
# GB24
# 0.8
# Xepi
# Rest
# Gy/h
# ST44
# mmHg
# 8.75
# 41.3
# F
# Oat
# Peak
# KI11
# Beye
# 1.14
# Cats
# Bali
# Boa
# Fog
# 4.4
# Dull
# BL29
# Snow
# Ruff
# nCi
# Ogen
# Togo
# J16
# 0.2
# Gaze
# Guam
# Cod
# KI3
# P1.7
# JVD
# mU/L
# a
# LR4
# O157
# On
# Ofev
# GV14
# ORB
# P1.6
# Alli
# Beer
# km
# 0.92
# 440
# TE18
# PE's
# Phi
# i
# 33.9
# 6/5
# 0.99
# 139
# 312
# GB6
# GB28
# 174
# TE13
# KI19
# 1.08
# GV24
# I
# Iron
# 335
# -1
# Jay
# Cafe
# tin
# kg-m
# PC7
# LYM
# Fume
# Fire
# Cox
# Bim
# ST32
# SI14
# Rusk
# SP8
# /12h
# 770
# Atom
# Lamb
# BL60
# Max
# BL25
# PC2
# 1.88
# Seed
# Rice
# mIU
# Tie
# Inca
# 250
# ST19
# boil
# CAU
# >
# G
# Per
# All
# 1.06
# J13
# Maid
# Chew
# in3
# Pond
# Judo
# Then
# GB25
# 135
# mCi
# 1667
# Glue
# -3
# Gold
# 97
# ug/L
# Asia
# Lora
# 10.3
# 2b
# 575
# uvea
# 0.72
# Mite
# 4
# L
# SI17
# 3000
# P1.1
# Bank
# 27.4
# HT5
# Bomb
# m3
# Now
# N24
# 190
# 620
# N14
# GV9
# f
# ST24
# Musa
# 10.5
# Flac
# Good
# 16
# GB21
# ST26
# ST12
# BL11
# Stop
# Zar
# J/mL
# 52.2
# /HPF
# KI26
# Cuba
# Belt
# 529
# 141
# 30
# mL/s
# PER
# 90
# 775
# 1875
# Boal
# Area
# Form
# 2.4
# b
# 10.7
# 18.2
# Poi
# Yews
# Wolf
# ST17
# Add
# 522
# 0
# -4
# 875
# 1/2
# x
# 360
# 31
# TE10
# 1200
# Milk
# Tau
# 145
# III
# KI8
# dm
# 110
# aVF
# HT9
# Farm
# 43
# BL62
# Hake
# TE17
# U/L
# PC5
# U/dL
# Corn
# Lai
# 333
# Long
# GB22
# Wind
# Kent
# Eel
# 16.1
# As
# CV24
# 11.5
# Ia
# Park
# Soak
# Suet
# 0.05
# IU/h
# CER
# km/h
# Zulu
# rpm
# Sloe
# 370
# ST30
# 218
# CV7
# LR11
# GB30
# Tea
# MJ/h
# hour
# Ox
# ST22
# 8.7
# cGy
# 3.17
# <
# mEq
# cSt
# TE14
# 57
# v/v
# C
# Peat
# Wasp
# 149
# <3
# 1140
# 11.4
# anus
# 19G
# ICCE
# 44
# Band
# 69
# TE20
# BL61
# GB23
# 5.2
# (m)
# N4.5
# Step
# SI3
# Kite
# LI16
# BL22
# 3.64
# Ling
# BL9
# ST20
# MHz
# HEA
# Chen
# limb
# BL64
# -2
# 30.8
# 0.6
# VI
# Upon
# GV16
# Stat
# lung
# CV15
# Fons
# 59
# And
# 330
# 224
# 348
# 15.4
# 29
# Unit
# 5.02
# Aves
# Gout
# ft3
# 1500
# 1.6
# h
# PC9
# 37
# Whey
# 396
# Tody
# Aloe
# 7.71
# 0.7
# Side
# 185
# BL21
# Tack
# GV11
# SI18
# um
# HT8
# SSD
# 0.17
# SI11
# LI11
# 0.14
# Bore
# Exit
# 1680
# Eta
# Siti
# UICC
# 48
# GB19
# 6/45
# MW 4
# RM 2
# LR3
# BL8
# Air
# mU
# 2.72
# 1.67
# GV10
# J1
# 2400
# Core
# BL34
# 385
# CV16
# Toad
# Fast
# Pork
# m
# ITP
# 12.5
# 14
# 26.3
# Crib
# Comb
# 2.25
# Date
# 1.09
# SI16
# 31.2
# 5.26
# 3320
# Miso
# 595
# lip
# Rare
# Ibis
# 6.66
# +5
# Seal
# GB14
# 10.4
# GB41
# GV8
# zinc
# 1.56
# ST35
# Wine
# Pila
# H2N2
# Rio
# Baza
# 240
# BL59
# Null
# GERD
# Oena
# 3.42
# 34.2
# Cast
# Mini
# 6.5

# %% [markdown]
# # 3. Annotate the recognized and negated terms
#
# Annotate by string matching the text to the lexicon downloaded, and apply negex trigger rules to separate negated terms

# %%
# %%time
df_result = get_patients_annotated_terms(unique_terms[:10], df)
df_result.to_csv('result.csv', index=False)
df_result = pd.read_csv('result.csv')
df_result.head(2)
# Out:
# CPU times: user 2.31 s, sys: 4 ms, total: 2.31 s
# Wall time: 2.34 s
#   negated_terms recognized_terms  \
# 0  OrderedSet()     OrderedSet()
# 1  OrderedSet()     OrderedSet()
#
#                                                                                       tagged_sentences
# 0  S O H Counters Report Type Record Type Subgroup Classifier 1,01TdvtyYejbW DS DS 1504 E O H [Repo...
# 1  The patient was transferred to **INSTITUTION for explantation of a pacemaker system that was fel...

# %% [markdown]
# ## 4. Compile terms for timeline view of the patient's record
#
# We compile terms (From each note, output:set of negated terms, set of non-negated terms) into a temporally ordered series of sets for each patient to create a timeline view of the patient’s record.
#
# The patient id and admission date are now __mocked__

# %%
# mock id and admission date

import random
import datetime

random_id, random_date = [], []
for i in range(df_result.shape[0]):
    n = random.randint(1,30)
    month = random.randint(1,12)
    day = random.randint(1,28)
    random_date.append(datetime.date(2020, month, day))
    random_id.append(n)
    
df_result['patient_id'] = random_id
df_result['admission_date'] = random_date

# %%
df_result_grouped_pos = df_result.sort_values(['patient_id', 'admission_date']).groupby(['patient_id'])['recognized_terms'].apply(temporally_ordered_list_join).reset_index()
df_result_grouped_neg = df_result.sort_values(['patient_id', 'admission_date']).groupby(['patient_id'])['negated_terms'].apply(temporally_ordered_list_join).reset_index()
df_result_grouped = df_result_grouped_pos.merge(df_result_grouped_neg, on='patient_id', how='left')
df_result_grouped.head(2)
# Out:
#    patient_id  \
# 0           1
# 1           2
#
#                                                                                       recognized_terms  \
# 0  [OrderedSet(), OrderedSet(), OrderedSet(), OrderedSet(), OrderedSet(), OrderedSet(), OrderedSet(...
# 1  [OrderedSet(), OrderedSet(), OrderedSet(), OrderedSet(), OrderedSet(), OrderedSet(), OrderedSet(...
#
#                                                                                          negated_terms
# 0  [OrderedSet(), OrderedSet(), OrderedSet(), OrderedSet(), OrderedSet(), OrderedSet(), OrderedSet(...
# 1  [OrderedSet(), OrderedSet(), OrderedSet(), OrderedSet(), OrderedSet(), OrderedSet(), OrderedSet(...

# %% [markdown]
# ## 5. Normalize and aggregate terms
#
# ### TODO:
# - Check terminologies for obtaining the correct lexicon (len(unique_term) < 5 and len(unique_term) < 2) still weird
# - Find better normalizer dict
#     - Google more
#     - [Subset from what's done] Derive normalizer from RXNorm UMLS
#     - [No good join] mere from PYM['RXNORM'] to the RXNATOMARCHIVE and RXNCONSO

# %%
normalizer_dict = get_rxnorm_normalizer()
# Out:
# Produced 14869 keys as the RXNorm normalizer dict.

# %%
normalizer_dict
# Out:
# {'a acalifornia hn hnlike atexas xa inactivated b bmassachusettslike': 'formula flulaval',
#  'a acalifornia hnlike': 'acaliforniahnvlike',
#  'a acalifornia hnlike avictoria b bbrisbane antigen bmassachusettslike': 'quadravalent',
#  'a acalifornia hnlike avictoria b bbrisbanelike bmassachusettslike': 'quadravalent',
#  'a acalifornia hnlike avictoria b bmassachusettslike': 'trivalent recombinant',
#  'a acalifornia hnlike avictoria b bwisconsinlike': 'intradermal fluzone formula',
#  'a acalifornia hnlike unt avictoria b bwisconsinlike': 'formula flumist',
#  'a atexas xa hn inactivated acaliforniahnvlike b bmassachusettslike': 'formula flulaval',
#  'a avictoria hnlike acaliforniahnvlike b bbrisbane antigen bmassachusettslike': 'quadravalent',
#  'a avictoria hnlike acaliforniahnvlike b bmassachusettslike': 'trivalent recombinant',
#  'a avictoria hnlike acaliforniahnvlike b bwisconsinlike': 'intradermal fluzone formula',
#  'a avictoria hnlike unt acaliforniahnvlike b bwisconsinlike': 'formula flumist',
#  'a hepatitis inactivated dose': 'unt in',
#  'a hepatitis inactivated pediatric dose': 'unt pediatricadolescent in',
#  'a hn antigen akansas b bmaryland': 'for fluad brisbanekansasmaryland generic vaccine',
#  'a hn monovalent': 'acaliforniahnvlike virus',
#  'a hn monovalent actuat': 'acaliforniahnvlike virus',
#  'a hn monovalent mcg per': 'acaliforniahnvlike virus',
#  'a in prefilled applicator': 'mucous membrane topical',
#  'a sulfate': 'sulfates',
#  'a vaccine acalifornia hn hnlike atexas xa inactivated b bbrisbane antigen bmassachusettslike': 'formula quad flulaval',
#  'a vaccine acalifornia hn hnlike atexas xa inactivated b bbrisbanelike bmassachusettslike': 'formula quad flulaval',
#  'a vaccine acalifornia hnlike avictoria b bbrisbane antigen bmassachusettslike': 'formula quad flulaval',
#  'a vaccine acalifornia hnlike avictoria b bbrisbanelike bmassachusettslike': 'formula quad flulaval',
#  'a vaccine atexas xa hn inactivated acaliforniahnvlike b bbrisbane antigen bmassachusettslike': 'formula quad flulaval',
#  'a vaccine avictoria hnlike acaliforniahnvlike b bbrisbane antigen bmassachusettslike': 'formula quad flulaval',
#  'aacetaminophen': 'apap',
#  'aactin': 'lactate',
#  'abacavir dolutegravir lamivudine': 'triumeq',
#  'abacavir lamivudine': 'epzicom',
#  'abacavir lamivudine zidovudine': 'trizivir',
#  'abbokinase': 'urokinase',
#  'abbokinase opencath': 'urokinase',
#  'abelcet per': 'complex amphotericin lipid b',
#  'abilify': 'aripiprazole oral',
#  'abilify discmelt': 'aripiprazole oral',
#  'absidia': 'lichtheimia',
#  'absidia allergenic': 'lichtheimia',
#  'absorbine': 'menthol',
#  'absorbine jr': 'menthol',
#  'absorbine jr antifungal': 'tolnaftate',
#  'abusedeterrent': 'embeda',
#  'abusedeterrent hydrocodone bitartrate': 'hysingla er',
#  'abusedeterrent morphine sulfate': 'morphabond',
#  'abusedeterrent morphine sulfate naltrexone hydrochloride': 'embeda',
#  'abusedeterrent oxycodone': 'xtampza er',
#  'abusedeterrent oxycodone hydrochloride': 'roxybond',
#  'acacia': 'gum arabic',
#  'acacia allergenic gm': 'gum arabic',
#  'acacia baileyana': 'wattle cootamundra',
#  'acacia gm': 'gum arabic',
#  'acacia longifolia': 'golden sydney wattle',
#  'acalifornia': 'antigen acaliforniahnvlike b',
#  'acalifornia bbrisbanelike': 'antigen acaliforniahnvlike bbrisbane',
#  'acalifornia hn strain unt aperth bbrisbane': 'trivalent formula',
#  'acalifornia hnlike': 'acaliforniahnvlike',
#  'acalifornia hnlike bbrisbanelike': 'antigen acaliforniahnvlike bbrisbane',
#  'acalifornia live attenuated strain': 'antigen acaliforniahnvlike',
#  'acalifornia xa': 'antigen acaliforniahnvlike b',
#  'acaliforniahnvlike': 'hnlike acalifornia',
#  'acaliforniahnvlike bbrisbane antigen': 'bbrisbanelike acalifornia',
#  'acaliforniahnvlike hn b bbrisbane antigen inactivated avictoria x aperth strain': 'intradermal fluzone formula',
#  'acaliforniahnvlike hn unt b bbrisbane antigen aperth strain': 'trivalent formula',
#  'acaliforniahnvlike hn unt b bbrisbane antigen attenuated aperth strain': 'formula flumist attenuatedtrivalent',
#  'acaliforniahnvlike hn unt b bbrisbane antigen live attenuated aperth strain': 'trivalent formula flumist',
#  'acaliforniahnvlike virus': 'monovalent a hn',
#  'acamprosate calcium': 'campral',
#  'acamprosate calcium enteric coated': 'oral release delayed campral',
#  'acamprosate enteric coated': 'oral release delayed',
#  'acarbose': 'precose',
#  'accolate': 'zafirlukast',
#  'accuneb inhalant': 'albuterol sulfate inhalation',
#  'accuneb per inhalant': 'albuterol sulfate inhalation',
#  'accupril': 'quinapril',
#  'accupro': 'quinapril',
#  'accuretic': 'hydrochlorothiazide quinapril',
#  'accuretic hctz': 'hydrochlorothiazide',
#  'accuretic hctz as hydrochloride': 'hydrochlorothiazide',
#  'accutane': 'isotretinoin',
#  'accuzyme': 'papain urea',
#  'aceate': 'acetate',
#  'acebrophylline': 'ambroxoltheophyllineacetate',
#  'acebutolol': 'sectral',
#  'acebutolol hydrochloride': 'sectral',
#  'acellular per pertussis vaccine diphtheria toxoid unt hepatitis b surface antigen poliovirus inactivated type mahoney mef saukett tetanus': 'dtaphepbipv',
#  'acellular per pertussis vaccine diphtheria toxoid unt inactivated poliovirus type mahoney mef saukett tetanus': 'dtapipv',
#  'acellular per pertussis vaccine diphtheria toxoid unt poliovirus inactivated type mahoney mef saukett tetanus': 'dtapipv',
#  'acellular pertussis diphtheria toxoid unt hepatitis b surface antigen poliovirus inactivated type mahoney mef saukett tetanus': 'pediarix',
#  'acellular pertussis diphtheria toxoid unt poliovirus inactivated type mahoney mef saukett tetanus': 'kinrix',
#  'acellular pertussis inactivated diphtheria toxoid unt hepatitis b surface antigen poliovirus type mahoney mef saukett tetanus': 'pediarix',
#  'acellular pertussis vaccine diphtheria toxoid unt hepatitis b surface antigen poliovirus inactivated type mahoney mef saukett tetanus': 'dtaphepbipv',
#  'acellular pertussis vaccine diphtheria toxoid unt poliovirus inactivated type mahoney mef saukett tetanus': 'dtapipv',
#  'acellular pertussis vaccine inactivated diphtheria toxoid unt hepatitis b surface antigen poliovirus type mahoney mef saukett tetanus': 'dtaphepbipv',
#  'acenocoumarol': 'sinthrome',
#  'aceph brand of acetaminophen': 'apap',
#  'acepril': 'captopril',
#  'acepromazine maleate': 'promace',
#  'acer macrophyllum': 'coast maple',
#  'acer negundo': 'maple box elder',
#  'acer rubrum': 'red maple',
#  'acer saccharinum': 'maple silver',
#  'acer saccharum': 'sugar maple',
#  'aceta': 'acetaminophen',
#  'acetadote gm per': 'acetylcysteine',
#  'acetagesic': 'acetaminophen phenyltoloxamine',
#  'acetaminophen': 'zydone apap',
#  'acetaminophen as hydrochloride': 'apap',
#  'acetaminophen ascorbic acid': 'vitamin apap c',
#  'acetaminophen ascorbic acid cineole': 'vitamin eucalyptol apap c',
#  'acetaminophen aspirin': 'strength extra body back excedrin',
#  'acetaminophen aspirin caffeine': 'vanquish',
#  'acetaminophen aspirin caffeine codeine phosphate salicylamide': 'ridapain',
#  'acetaminophen aspirin caffeine oral tablet': 'strength and kit extra action pain triple reliever pm caplets excedrin',
#  'acetaminophen aspirin caffeine salicylamide': 'saleto',
#  'acetaminophen aspirin diphenhydramine citrate': 'excedrin action triple pm',
#  'acetaminophen b vitamin': 'apap pyridoxine',
#  'acetaminophen benzhydrocodone': 'apadaz',
#  'acetaminophen bitartrate': 'zydone apap',
#  'acetaminophen butalbital': 'tencon',
#  'acetaminophen butalbital caffeine': 'zebutal',
#  'acetaminophen butalbital caffeine tablet': 'capsule',
#  'acetaminophen c vitamin': 'apap vitc',
#  'acetaminophen caffeine': 'tension headache excedrin',
#  'acetaminophen caffeine dihydrocodeine bitartrate': 'trezix',
#  'acetaminophen caffeine isometheptene mucate': 'prodrin',
#  'acetaminophen caffeine magnesium salicylate': 'backprin',
#  'acetaminophen caffeine phenyltoloxamine citrate salicylamide': 'durabac',
#  'acetaminophen chlophedianol hydrochloride pyrilamine maleate': 'ninjacof a in',
#  'acetaminophen chloralantipyrine': 'mitride apap dichloralphenazone',
#  'acetaminophen chloralantipyrine isometheptene': 'migratine',
#  'acetaminophen chlorpheniramine codeine phosphate phenylephrine': 'colrex',
#  'acetaminophen chlorpheniramine maleate codeine phosphate phenylephrine hydrochloride': 'colrex',
#  'acetaminophen codeine phosphate': 'tylenol',
#  'acetaminophen dichloralantipyrine': 'mitride apap dichloralphenazone',
#  'acetaminophen dichloralantipyrine isometheptene': 'migratine',
#  'acetaminophen dichloralphenazone isometheptene': 'nodolor',
#  'acetaminophen dihydroergotamine': 'dhe apap',
#  'acetaminophen diphenhydramine citrate': 'excedrin pm',
#  'acetaminophen diphenhydramine hydrochloride': 'tylenol pm',
#  'acetaminophen enteric coated': 'release delayed oral apap',
#  'acetaminophen extended release oral tablet': 'extendedrelief pain tylenol arthritis caplet',
#  'acetaminophen extended release tablet': 'extendedrelief pain tylenol arthritis caplet',
#  'acetaminophen guaifenesin': 'apap gg',
#  'acetaminophen hbr': 'apap hydrobromide',
#  'acetaminophen hbr hcl': 'hydrochloride apap hydrobromide',
#  'acetaminophen hbr hcl per': 'hydrochloride apap hydrobromide',
#  'acetaminophen hbr hcl per grannules for': 'hydrochloride apap hydrobromide',
#  'acetaminophen hcl': 'hydrochloride maleate apap',
#  'acetaminophen hcl powder': 'hydrochloride apap granules',
#  'acetaminophen hour': 'hydrochloride apap oral hr',
#  'acetaminophen hydrobromide': 'apap hbr',
#  'acetaminophen hydrochloride': 'hcl compound hycomine apap',
#  'acetaminophen hydrocodone bitartrate': 'zyfrel in',
#  'acetaminophen magnesium salicylate': 'painaid brf',
#  'acetaminophen magnesium salicylate pamabrom': 'pamprin formula cramp',
#  'acetaminophen oral tablet': 'extendedrelief pain tylenol arthritis caplet',
#  'acetaminophen oxycodone hydrochloride': 'xolox',
#  'acetaminophen pamabrom': 'tylenol relief womens menstrual',
#  'acetaminophen pamabrom pyrilamine maleate': 'syncol multisymptom relief',
#  'acetaminophen pentazocine': 'talacen',
#  'acetaminophen per': 'hydrochloride apap',
#  'acetaminophen per oz': 'apap',
#  'acetaminophen phenylpropanolamine': 'carbidopa apap',
#  'acetaminophen phenyltoloxamine': 'rhinoflex',
#  'acetaminophen phenyltoloxamine citrate': 'zgesic',
#  'acetaminophen phenyltoloxamine citrate salicylamide': 'edflex',
#  'acetaminophen phosphate': 'capital and in',
#  'acetaminophen potassium': 'k apap',
#  'acetaminophen potassium enteric coated': 'release delayed apap oral pot',
#  'acetaminophen powder': 'granules apap',
#  'acetaminophen propoxyphene napsylate': 'propacet',
#  'acetaminophen pyridoxine': 'vitamin apap b',
#  'acetaminophen secbutabarbital': 'apap butabarbital',
#  'acetaminophen tablet': 'apap capsule',
#  'acetaminophen thiamine': 'vitb apap',
#  'acetaminophen tramadol hydrochloride': 'ultracet',
#  'acetasol': 'acetic acid',
#  'acetasol hc': 'acetic acid hydrocortisone',
#  'acetate': 'oral',
#  'acetate for depot suspension norethindrone': 'ac in noreth',
#  'acetate for depot suspension per norethindrone': 'ac in noreth',
#  'acetate hydrochloride pad': 'wipe hcl gm',
#  'acetate meq cysteine histidine isoleucine leucine lysine methionine phenylalanine sodium bisulfite chloride threonine tryptophan valine': 'nephramine',
#  'acetate norethindrone pack': 'kit month ac in noreth',
#  'acetatedlalpha': 'acetate dlalpha',
#  'acetazolamide': 'diamox sequels',
#  'acetic': 'jelly',
#  'acetic acid': 'vosol',
#  'acetic acid chlorhexidine gluconate ketoconazole': 'malaket',
#  'acetic acid hydrocortisone': 'hc vosol',
#  'acetic acid otic': 'ear borofair',
#  'acetic acid oxyquinoline sulfate': 'relagard',
#  'acetminophen': 'apap',
#  'acetminophen per': 'apap',
#  'acetocot': 'triamcinolone',
#  'acetohexamide': 'dymelor',
#  'acetone tea tree oil': 'frog keratex disinfectant',
#  'acetorphan': 'racecadotril',
#  'acetylaminocaproic': 'acexamic',
#  'acetylcarbromal': 'paxarel',
#  'acetylcarnitine': 'levacecarnine',
#  'acetylcarnitine hcl': 'hydrochloride levacecarnine',
#  'acetylcholine chloride': 'miochole in',
#  'acetylcholine chloride injectable': 'ophthalmic miochole in',
#  'acetylcysteine': 'mucomyst',
#  'acetylcysteine inhalant': 'inhalation mucomyst',
#  'acetylcysteine oral': 'inhalation mucomyst',
#  'acetyldigoxins': 'acetyldigoxin',
#  'acetylglucosamine': 'nacetylglucosamine',
#  'acetylglycyrrhetinic acid salt': 'acetoxolone',
#  'acetylsalicylic acid': 'aspirin',
#  'acetylsysteine': 'acetylcysteine',
#  'acetyltributylcitrate': 'acetyltributyl citrate',
#  'acetyltryptophanate': 'nacetyldltryptophan',
#  'achristchurch nib acalifornia': 'antigen acaliforniahnvlike b',
#  'achromycin': 'tetracycline',
#  'achromycin v': 'tetracycline',
#  'aciclovir': 'acyclovir',
#  'acid': 'sodium',
#  'acid ethyl esters': 'acids fatty',
#  'acid ethyl esters usp': 'acids fatty',
#  'acid gone': 'carbonate hydroxide aluminum magnesium',
#  'acid gone antacid': 'trisilicate hydroxide aluminum magnesium',
#  'acidanhydrous': 'acid anhydrous',
#  'acidic jelly': 'acetic acid',
#  'acids': 'acid',
#  'acidulated phosphate fluoride': 'flur rinse phos',
#  'acillin': 'v penicillin',
#  'aciphex': 'rabeprazole sodium oral',
#  'aciphex delayed release capsule': 'rabeprazole sodium oral granules',
#  'aciphex delayed release sprinkle capsule': 'rabeprazole sodium granules',
#  'aciphex enteric coated': 'release delayed sodium rabeprazole oral',
#  'aciphex enteric coated capsule': 'rabeprazole sodium oral granules',
#  'acitak': 'cimetidine',
#  'acitretin': 'soriatane',
#  'aclarubicin': 'aclacin',
#  'aclometasone': 'alclometasone',
#  'aclometasone gm': 'alclometasone',
#  'aclovate': 'alclometasone',
#  'aclovate gm': 'alclometasone dipropionate',
#  'acne brand of benozyl': 'benzoyl',
#  'acnomel': 'sulfur resorcinol',
#  'acnotex': 'sulfur resorcinol',
#  'acoflam enteric coated': 'release delayed diclofenac sodium oral',
#  'acoflam retard': 'sodium diclofenac oral',
#  'acriflavine': 'euflavine',
#  'acriflavine gentian violet sodium propionate': 'blukote',
#  'acriflavine hydrochloride': 'acriflavinium chloride',
#  'acrivastine pseudoephedrine hydrochloride': 'semprexd',
#  'acrylodimethyltaurate': 'acryloyldimethyltaurate',
#  'act rinse': 'sodium',
#  'actacin': 'pseudoephedrine triprolidine',
#  'actamin': 'apap',
#  'actedril': 'pseudoephedrine triprolidine',
#  'actemra': 'tocilizumab',
#  'acth': 'corticotropin',
#  'acth gel': 'corticotropin',
#  'acth hp': 'corticotropin',
#  'actibine': 'yohimbine',
#  'acticort': 'hydrocortisone',
#  'actidil': 'triprolidine',
#  'actifed': 'pseudoephedrine triprolidine',
#  'actifed allergy daynight': 'diphenhydramine pseudoephedrine',
#  'actinex': 'masoprocol',
#  'actiq': 'fentanyl oral',
#  'actiq as citrate mcg': 'oral',
#  'actiq mcg': 'fentanyl oral',
#  'activated': 'plus ds',
#  'activated charcoal': 'sorbitol plus actidose',
#  'activated charcoal enteric coated': 'charflo release delayed oral',
#  'activated enteric coated': 'release delayed plus oral ds',
#  'active q in': 'ubiquinol',
#  'activon joint muscle': 'menthol',
#  'actoplus met xr': 'pioglitazone metformin hydrochloride hr oral',
#  'actos': 'pioglitazone',
#  'actrapid': 'regular insulin',
#  'actrapid penfill': 'regular insulin',
#  'actron': 'ketoprofen',
#  'actuat': 'untactuat',
#  'actuat epinephrine': 'primatene actuations mist inhal',
#  'actuat hydrochloride phenylephrine': 'actuations hclphenylephrine inhal',
#  'actuat inhalant': 'sodium inhalation',
#  'actuat isoproterenol hydrochloride phenylephrine bitartrate': 'actuations duomedihaler inhal',
#  'actuat isoproterenol sulfate': 'actuations medihaleriso inhal',
#  'actuat loxapine': 'adasuve actuation inhal',
#  'actuat testosterone': 'axiron',
#  'actuat zanamivir': 'relenza blisters diskhaler inhal',
#  'acular': 'ketorolac',
#  'acupan': 'nefopam',
#  'acuprin': 'aspirin',
#  'acyclovir': 'zovirax',
#  'acyclovir as sodium': 'acycycloguanosine',
#  'acyclovir equivalent to sodium in': 'acycycloguanosine',
#  'acyclovir lidocaine hydrochloride': 'lidovir',
#  'acyclovir per': 'acycycloguanosine',
#  'acys': 'acetylcysteine',
#  'adalat': 'oral nifedipine',
#  'adalat ar': 'oral nifedipine',
#  'adalat ar hour': 'oral nifedipine hr',
#  'adalat cc': 'oral nifedipine',
#  'adalat la': 'oral nifedipine',
#  'adalat la hour': 'oral nifedipine hr',
#  'adalat retard': 'oral nifedipine',
#  'adalat retard hour': 'oral nifedipine hr',
#  'adalate': 'nifedipine',
#  'adalate lp': 'oral nifedipine',
#  'adalate lp hour': 'oral nifedipine hr',
#  'adapalene benzoyl peroxide': 'epiduo forte',
#  'adapin': 'doxepin',
#  'adbeon': 'betamethasone',
#  'adcortyl': 'triamcinolone',
#  'adderall': 'amphetamine aspartate sulfate dextroamphetamine saccharate oral',
#  'adderall xr': 'amphetamine aspartate sulfate dextroamphetamine saccharate oral',
#  'adenocard': 'adenosine',
#  'adenosine': 'adenoscan in',
#  'adenosine monophosphate': 'myoden',
#  'adequam': 'adequan',
#  'adequam im per': 'glycosaminoglycan polysulfated',
#  'adequan ia per': 'glycosaminoglycan polysulfated',
#  'aderall': 'adderall',
#  'adifax': 'dexfenfluramine',
#  'adipexp': 'phentermine',
#  'adipine mr': 'oral nifedipine',
#  'adipine mr hour': 'oral nifedipine hr',
#  'adipost': 'tartrate oral phendimetrazine',
#  'adotrastuzumab emtansine': 'trastuzumab',
#  'adoxa': 'doxycycline',
#  'adprin b': 'acetaminophen',
#  'adrabetadex': 'ms hydroxypropylbetadex',
#  'adrenaclick': 'nda epinephrine',
#  'adrenalin': 'epinephrine',
#  'adrenaline': 'epinephrine',
#  'adrucil': 'fluorouracil',
#  'adsorbocarpine': 'pilocarpine',
#  'adult low strength': 'aspirin regimen',
#  'adult skin protectant': 'oxide dimethicone zinc',
#  'advanced formula digel': 'hydroxide magnesium carbonate simethicone calcium',
#  'advantage contraceptive': 'nonoxynol',
#  'advantage contraceptive topical': 'vaginal nonoxynol',
#  'advicor': 'vitb oral lovastatin',
#  'advicor niacin': 'vitb oral',
#  'advil': 'ibuprofen',
#  'advil childrens': 'ibuprofen',
#  'adzenys': 'amphetamine',
#  'adzenys xrodt': 'amphetamine',
#  'aedes taeniorhynchus': 'mosquito',
#  'aeroaid': 'thimerosal',
#  'aerobec': 'qvar',
#  'aerobec forte': 'qvar',
#  'aerodine': 'povidoneiodine',
#  'aerohist': 'oral',
#  'aerolate': 'oral theophylline',
#  'aerolate iii': 'oral theophylline',
#  'aerolate jr': 'oral theophylline',
#  'aerolate sr': 'theophylline',
#  'aerosebdex': 'dexamethasone',
#  'aerosebhc': 'hydrocortisone',
#  'aerospan': 'flunisolide',
#  'aerospan mcginhal actuations': 'flunisolide actuat',
#  'aerosporin': 'polymyxin b',
#  'aerozoin': 'compound usp benzoin tincture',
#  'afatinib': 'gilotrif',
#  'afeditab cr': 'oral nifedipine',
#  'afinitor disperz per': 'everolimus',
#  'aflaxen': 'naproxen',
#  'aflaxen enteric coated': 'oral release delayed naproxen',
#  'afluria': 'kong acalifornia virus b antigen bbrisbane influenza hn ahong a',
#  'afluria quadrivalent vaccine': 'kong virus asingaporegp b antigen bphuket bbrisbane influenza hn ahong a',
#  'afluria vaccine': 'bmaryland virus asingaporegp b antigen influenza hn asingaporeinfimh a',
#  'afrazine': 'oxymetazoline',
#  'afrin': 'oxymetazoline',
#  'afrinol': 'hydrochloride oral pseudoephedrine',
#  'afrinol hour': 'oral pseudoephedrine',
#  'ag tussin': 'hydrocodone chlorpheniramine pseudoephedrine',
#  'agaricic': 'agaric',
#  'agenerase': 'amprenavir',
#  'agerite alba': 'monobenzone',
#  'aggrastat in': 'tirofiban',
#  'aggrastat mcg per': 'tirofiban',
#  'aggrastat per': 'tirofiban',
#  'aggrenox': 'release hr extended aspirin dipyridamole',
#  'aggrenox asa': 'release aspirin hr extended',
#  'agoral': 'phenolphthalein mineral oil',
#  'agrimectin': 'ivermectin',
#  'agrostis gigantea': 'grass redtop',
#  'ahchew d': 'phenylephrine',
#  'ailanthus': 'anthoxanthum',
#  'ailanthus altissima': 'tree heaven of',
#  'ailanthus odoratum': 'vernal sweet grass',
#  'airet inhalant': 'albuterol inhalation',
#  'akarpine': 'pilocarpine',
#  'akbeta': 'levobunolol',
#  'akchlor': 'chloramphenicol',
#  'akcide': 'prednisolone sulfacetamide',
#  'akcon': 'naphazoline',
#  'akcona': 'naphazoline pheniramine',
#  'akdex': 'dexamethasone',
#  'akdilate': 'phenylephrine',
#  'aknefrin': 'phenylephrine',
#  'aknemin': 'minocycline',
#  'aknemycin': 'erythromycin',
#  'akneodex': 'dexamethasone neomycin',
#  'akpentolate': 'cyclopentolate',
#  'akpred': 'prednisolone',
#  'akpro': 'dipivefrin',
#  'akspore': 'b gramicidin neomycin polymyxin',
#  'akspore hc': 'b hydrocortisone neomycin polymyxin',
#  'aksulf': 'sulfacetamide',
#  'aktaine': 'proparacaine',
#  'aktob': 'tobramycin',
#  'aktracin': 'bacitracin',
#  'aktrol': 'b dexamethasone neomycin polymyxin',
#  'akwa tears': 'oil mineral lanolin petrolatum',
#  'alacort': 'hydrocortisone',
#  'alagesic': 'acetaminophen caffeine butalbital',
#  'alagesic acetaminophen per': 'apap',
#  'alamag': 'hydroxide aluminum magnesium',
#  'alamag plus': 'simethicone hydroxide aluminum magnesium',
#  'alamast': 'pemirolast',
#  'alanine': 'lalanine',
#  'alanine arginine aspartate cysteine glutamate glycine histidine isoleucine leucine lysine methionine phenylalanine proline serine sodium acetate meq chloride metabisulfite taurine threonine tryptophan tyrosine valine': 'trophamine',
#  'alanine arginine aspartate cysteine glutamate glycine histidine isoleucine leucine lysine methionine phenylalanine proline serine taurine threonine tryptophan tyrosine valine': 'premasol',
#  'alanine arginine aspartate glucose glutamate glycine histidine isoleucine leucine lysine magnesium chloride meq methionine phenylalanine potassium proline serine sodium phosphate threonine tryptophan tyrosine valine': 'ii aminosyn dextrose in m',
#  'alanine arginine aspartate glucose glutamate glycine histidine isoleucine leucine lysine methionine nacetyltyrosine phenylalanine proline serine threonine tryptophan valine': 'aminosyn ii',
#  'alanine arginine glycine histidine isoleucine leucine lysine methionine phenylalanine proline serine threonine tryptophan tyrosine valine': 'travasol',
#  'alanine cysteine glycine histidine isoleucine leucine lysine methionine phenylalanine phosphoric acid proline serine threonine tryptophan valine': 'freamine iii',
#  'alaquin': 'clioquinol hydrocortisone',
#  'alascalp hp': 'hydrocortisone',
#  'alatet': 'tetracycline',
#  'alavert': 'oral loratadine',
#  'alavert d': 'oral',
#  'alavert hr': 'loratadine',
#  'alaway': 'ketotifen',
#  'alba': 'tomentosa',
#  'albalon': 'naphazoline',
#  'albamycin': 'novobiocin',
#  'albendazole': 'valbazen',
#  'albenza': 'albendazole',
#  'albiglutide prefilled syringe': 'injector tanzeum pen in',
#  'albucid': 'sulfacetamide',
#  'albumin human usp': 'plasbumin in',
#  'albuminhuman epoetin alfa': 'erythropoietin',
#  'albuterol': 'vospire er',
#  'albuterol hour': 'oral hr volmax',
#  'albuterol inhalant': 'inhalation ventolin rotacaps',
#  'albuterol inhalant solution': 'nda inhaler proventil metered dose',
#  'albuterol ipratropium bromide': 'duoneb in',
#  'albuterol ipratropium bromide inhalant': 'inhalation in',
#  'albuterol sulfate inhalant': 'accuneb inhalation',
#  'albutrepenonacog alfa': 'factor ix',
#  'alcaftadine': 'lastacaft',
#  'alcaine': 'proparacaine',
#  'alchol': 'alcohol',
#  'alclometasone': 'modrasone',
#  'alcoholdenatured': 'ethanol denatured',
#  'aldactazide': 'hydrochlorothiazide spironolactone',
#  'aldactone': 'spironolactone',
#  'aldara': 'imiquimod',
#  'aldesleukin': 'proleukin',
#  'aldesleukin unt': 'proleukin',
#  'aldoclor': 'methyldopa chlorothiazide',
#  'aldomet': 'methyldopa',
#  'aldoril hctz': 'hydrochlorothiazide',
#  'aldoril hydrochlorothiazide': 'hctz',
#  'alendronic acid': 'sodium in alendronate',
#  'alendronic acid cholecalciferol': 'fosamax plus d',
#  'alendronic acid cholecalciferol unt': 'fosamax plus d',
#  'alendronic acid per': 'sodium in alendronate',
#  'alendronic acid per oz for solution': 'sodium alendronate',
#  'alenic alka': 'carbonate hydroxide aluminum magnesium',
#  'alera': 'hydroquinone',
#  'alerdryl': 'diphenhydramine',
#  'alesse': 'estradiol ethinyl levonorgestrel',
#  'aleve': 'naproxen',
#  'alexan': 'cytarabine',
#  'alfacalcidol': 'onealpha',
#  'alfalfa': 'medicago sativa',
#  'alfalfa gm': 'medicago sativa',
#  'alfan': 'alphan',
#  'alfathrombin': 'recothrom in',
#  'alfaxolone': 'alfaxalone',
#  'alfenta': 'alfentanil',
#  'alfentanil': 'concentrate rapifen',
#  'alferon n': 'interferon alfan',
#  'alfuzosin hydrochloride': 'uroxatral',
#  'algal fungi': 'phycomyces gm blakesleeanus',
#  'algeldrate': 'hydroxide aluminum gel',
#  'alginic compound': 'trisilicate hydroxide aluminum magnesium',
#  'algitec': 'cimetidine acid alginic',
#  'alicylic': 'salicylic',
#  'alidrin': 'isometheptene dichloralphenazone acetaminophen',
#  'alidrin acetaminophen': 'apap',
#  'alidrin apap': 'acetaminophen',
#  'aliflex acetaminophen': 'apap',
#  'alimix': 'cisapride',
#  'alinia': 'nitazoxanide',
#  'alinia per': 'nitazoxanide',
#  'aliskiren aodipine': 'tekao',
#  'aliskiren aodipine hydrochlorothiazide': 'amturnide',
#  'aliskiren hctz': 'tekturna hct',
#  'aliskiren hydrochlorothiazide': 'tekturna hct',
#  'alkabel': 'oral',
#  'alkabel atropine sulfate hyoscyamine phenobarbital scopolamine hydrobromide': 'alkabelsr oral',
#  'alkamints': 'carbonate calcium',
#  'alkeran': 'melphalan',
#  'alkets': 'carbonate calcium',
#  'alkums': 'carbonate calcium',
#  'all clear': 'hydrochloride naphazoline',
#  'all day c cr': 'ascorbic acid',
#  'allantoin': 'theraworx',
#  'allantoin benzalkonium chloride': 'hands action first in',
#  'allantoin benzalkonium chloride benzyl alcohol': 'shingreleev',
#  'allantoin benzethonium chloride': 'berberex wound cleanser',
#  'allantoin benzocaine camphor petrolatum': 'sore cold therapy anbesol',
#  'allantoin benzocaine camphor petrolatum white': 'sore cold therapy anbesol',
#  'allantoin glycerin': 'neutracett',
#  'allantoin hydrochloride': 'hcl allatoin',
#  'allantoin lidocaine petrolatum': 'vexad',
#  'allantoin ointment': 'stick run guard',
#  'allay': 'acetaminophen hydrocodone',
#  'allegra': 'hydrochloride oral fexofenadine',
#  'allegra cooling relief antiitch hcl': 'hydrochloride',
#  'allegra d': 'allegrad',
#  'allegra d allergy congestion': 'oral allegrad',
#  'allegra d allergy congestion fexofenadine hydrochloride pseudoepehedrine': 'oral allegrad',
#  'allegra d allergy congestion pseudoepehedrine': 'oral pseudoephedrine',
#  'allegra d hour': 'oral',
#  'allegrad hour': 'oral hr',
#  'allegrad hour pseudoephedrine': 'pseudoepehedrine congestion hr oral allergy allegra d',
#  'allegron': 'nortriptyline',
#  'allenrolfea occidentalis': 'iodine bush',
#  'allerchlor': 'chlorpheniramine',
#  'allerchlor in': 'maleate chlorpheniramine',
#  'allerclear': 'oral',
#  'allerclear loratadine pseudoephedrine sulfate': 'oral allercleard',
#  'allerclear pseudeoephedrine': 'oral pseudoephedrine',
#  'allercon': 'pseudoephedrine triprolidine',
#  'allerest eye drops': 'naphazoline',
#  'allerest hour': 'oxymetazoline',
#  'allerfrim': 'pseudoephedrine triprolidine',
#  'allergenic': 'pollen maple',
#  'allergenic arrhizus mold': 'oryzae',
#  'allergenic ash arizona': 'velutina fraxinus',
#  'allergenic beech': 'pollen grandifolia fagus',
#  'allergenic cat sp': 'catus',
#  'allergenic dander': 'skin',
#  'allergenic extract gm per': 'muskmelon',
#  'allergenic gm': 'cow milk',
#  'allergenic gm per': 'florentina var',
#  'allergenic horse dander': 'skin equus caballus',
#  'allergenic mold': 'gm var',
#  'allergenic monilia': 'chrysonilia',
#  'allergenic pecan': 'pollen carya illinoinensis',
#  'allergenic yellow dock': 'rumex crispus',
#  'allergiac': 'diphenhydramine',
#  'allerhist': 'clemastine',
#  'allerhistd': 'phenylpropanolamine hydrochloride clemastine oral fumarate',
#  'allerhistd hour': 'oral clemastine phenylpropanolamine',
#  'allermax': 'hydrochloride diphenhydramine',
#  'allersol': 'naphazoline',
#  'allersola hcl': 'hydrochloride allersol a',
#  'allertec d dihydrochloride': 'oral',
#  'allerx am': 'oral',
#  'allerx df am': 'oral',
#  'allerx methscopolamine nitrate pseudoephedrine hydrochloride': 'oral allerrx',
#  'allerx pe am': 'oral',
#  'allerx pm': 'oral',
#  'allerxd': 'oral methscopolamine pseudoephedrine',
#  'allfen': 'oral guaifenesin',
#  'allfen c': 'oral',
#  'allfen cx': 'oral',
#  'allfen hour': 'oral guaifenesin hr',
#  'allfen reformulated mar': 'oral',
#  'allopurinol': 'zyloprim',
#  'allopurinol lesinurad': 'duzallo',
#  'allscale': 'polycarpa gm atriplex',
#  'allylpropymal': 'aprobarbital',
#  'almacone': 'simethicone hydroxide aluminum magnesium',
#  'almazine': 'lorazepam',
#  'almodan': 'amoxicillin',
#  'almora': 'gluconate magnesium',
#  'alnus incana ssp rugosa': 'alder tag',
#  'alnus incana subsp rugosa': 'alder tag',
#  'alnus rhombifolia': 'white alder',
#  'alnus rubra': 'red alder',
#  'alocril': 'nedocromil',
#  'aloe cort': 'hydrocortisone',
#  'aloe polysaccharide hydrocortisone acetate iodoquinol': 'alcortin a',
#  'aloe polysaccharide iodoquinol': 'quinja',
#  'aloe vesta': 'miconazole',
#  'aloe vesta daily moisturizer topial': 'topical dimethicone',
#  'aloe vesta skin conditioner': 'dimethicone',
#  'alogliptin metformin hydrochloride': 'kazano',
#  'alogliptin pioglitazone': 'oseni',
#  'alohgel': 'hydroxide aluminum',
#  'alomide': 'lodoxamide',
#  'alophen': 'phenolphthalein',
#  'alophen pillschocolate': 'phenolphthalein',
#  'alophen reformulated jan': 'oral bisacodyl',
#  'alophen reformulated jan enteric coated': 'oral release delayed bisacodyl',
#  'aloquin and polysaccharides': 'polysaccharide',
#  'alor': 'aspirin hydrocodone',
#  'aloral': 'allopurinol',
#  'aloxi': 'palonosetron',
#  'alpain': 'citrate',
#  'alpain apap': 'citrate acetaminophen',
#  'alpatocopherol': 'vitamin e',
#  'alpha': 'alfa',
#  'alpha a tocopherol cholecalciferol vitamin': 'repro vital e',
#  'alpha lipoic coenzyme q dltocopherol': 'ubidecarenone tocopheroldlalpha unt thioctic',
#  'alpha tocopherol': 'vitamin e',
#  'alpha tocopherol ascorbic acid cholecalciferol copper sulfate folic iron carbonyl magnesium oxide pyridoxine hydrochloride retinol acetate riboflavin thiamine mononitrate zinc oral calcium carbonate': 'zn count a c e d ca fe cu',
#  'alpha tocopherol ascorbic acid cholecalciferol dioctyl sulfosuccinic salt folic pyridoxine hydrochloride riboflavin thiamine mononitrate': 'docusate iron c e d',
#  'alpha tocopherol ascorbic acid cholecalciferol folic pyridoxine hydrochloride riboflavin thiamine mononitrate': 'iron c e d',
#  'alpha tocopherol cholecalciferol': 'repro d vital e',
#  'alpha tocopherol cholecalciferol dioctyl sulfosuccinic acid salt folate hydrochloride riboflavin mononitrate': 'iron docusate e d',
#  'alpha tocopherol cholecalciferol dioctyl sulfosuccinic acid salt folate hydrochloride riboflavin vitb mononitrate': 'iron docusate e d',
#  'alpha tocopherol cholecalciferol dioctyl sulfosuccinic acid salt folate vitb hydrochloride riboflavin mononitrate': 'iron docusate e d',
#  'alpha tocopherol cholecalciferol doss folate hydrochloride riboflavin mononitrate': 'iron docusate e d',
#  'alpha tocopherol cholecalciferol doss folate hydrochloride riboflavin vitb mononitrate': 'iron docusate e d',
#  'alpha tocopherol cholecalciferol doss folate vitb hydrochloride riboflavin mononitrate': 'iron docusate e d',
#  'alpha tocopherol cholecalciferol vitamin': 'd vital e',
#  'alpha tocopherol unt ascorbic acid docosahexaenoic eicosapentaenoic ferrous fumarate folic pyridoxine tricalcium phosphate': 'one natelle',
#  'alpha tocopherol vitc cholecalciferol dioctyl sulfosuccinic acid salt folate hydrochloride riboflavin mononitrate': 'docusate iron c e d',
#  'alpha tocopherol vitc cholecalciferol dioctyl sulfosuccinic acid salt folate hydrochloride riboflavin vitb mononitrate': 'docusate iron c e d',
#  'alpha tocopherol vitc cholecalciferol dioctyl sulfosuccinic acid salt folate vitb hydrochloride riboflavin mononitrate': 'docusate iron c e d',
#  'alpha tocopherol vitc cholecalciferol doss folate hydrochloride riboflavin mononitrate': 'docusate iron c e d',
#  'alpha tocopherol vitc cholecalciferol doss folate hydrochloride riboflavin vitb mononitrate': 'docusate iron c e d',
#  'alpha tocopherol vitc cholecalciferol doss folate vitb hydrochloride riboflavin mononitrate': 'docusate iron c e d',
#  'alphaamylases': 'alphaamylase',
#  'alphadgalactosidase enzyme': 'prevention gasx',
#  'alphafluoroclobetasol': 'halobetasol',
#  'alphagan': 'brimonidine',
#  'alphaglucomannan': 'glucomannan',
#  'alphahydroxyprogesterone': 'usp hydroxyprogesterone',
#  'alphaketoglutarate': 'oxoglutarate',
#  'alphalipoic': 'thioctic',
#  'alphamethylprednisolone hemisuccinate': 'methylprednisolone succinate',
#  'alphaparin': 'certoparin',
#  'alphaquin hp': 'hydroquinone',
#  'alphathrombin': 'recothrom in',
#  'alphatocopherol': 'vitamin unt e',
#  'alphatocopherol a acetate ascorbic b acid biotin dexpanthenol ergocalciferol folic niacinamide pyridoxine hydrochloride riboflavin thiamine vitamin k': 'mvi pediatric',
#  'alphatocopherol a acetate vitc biotin b d dexpanthenol vitamin folate niacinamide hydrochloride riboflavin k': 'mvi pediatric',
#  'alphatocopherol a acetate vitc biotin b d dexpanthenol vitamin folate niacinamide hydrochloride riboflavin vitb k': 'mvi pediatric',
#  'alphatocopherol a acetate vitc biotin b d dexpanthenol vitamin folate niacinamide vitb hydrochloride riboflavin k': 'mvi pediatric',
#  'alphatocopherol a acetate vitc biotin b dexpanthenol vitd folate niacinamide vitamin hydrochloride riboflavin k': 'mvi pediatric',
#  'alphatocopherol a acetate vitc biotin b dexpanthenol vitd folate niacinamide vitamin hydrochloride riboflavin vitb k': 'mvi pediatric',
#  'alphatocopherol c acetate vitamin biotin b cholecalciferol dexpanthenol folate niacinamide hydrochloride retinyl palmitate riboflavin vitb k': 'pediatric infuvite',
#  'alphatocopherol c acetate vitamin biotin b cholecalciferol dexpanthenol folate niacinamide vitb hydrochloride retinyl palmitate riboflavin k': 'pediatric infuvite',
#  'alphatocopherol d': 'dalphatocopheryl',
#  'alphatocopherol dha epa': 'acid eicosapentaenoic vitamin docosahexaenoic e',
#  'alphatocopherol ubidecarenone': 'vitamin acetate coq e',
#  'alphatrex': 'betamethasone',
#  'alphavase': 'prazosin',
#  'alphen expectorant per': 'hydrochloride',
#  'alphodith': 'anthralin',
#  'alprazolam': 'xanax xr',
#  'alprostadil': 'prostin vr',
#  'alrex': 'loteprednol etabonate',
#  'alrheumat': 'ketoprofen',
#  'alsosetron': 'alosetron',
#  'altace': 'ramipril',
#  'altacite': 'hydrotalcite',
#  'altaryl': 'diphenhydramine',
#  'altenol': 'acetaminophen',
#  'alternagel': 'hydroxide aluminum',
#  'alternata': 'tenuis',
#  'altinac': 'tretinoin',
#  'altocor': 'oral lovastatin',
#  'altoprev': 'oral lovastatin',
#  'altorant': 'guaifenesin',
#  'altretamine': 'hexalen',
#  'alucap': 'hydroxide aluminum',
#  'aluline': 'allopurinol',
#  'aluminium': 'aluminum',
#  'aluminum': 'aluminium',
#  'aluminum chlorhydrate': 'chlorohydrate aluminium',
#  'aluminum hydroxide': 'dialume',
#  'aluminum hydroxide magnesium carbonate': 'strength regular gaviscon in',
#  'aluminum hydroxide magnesium simethicone': 'rimox plus in',
#  'aluminum hydroxide magnesium trisilicate': 'gavsicon strength regular',
#  'aluminum hydroxide per': 'strength extra gaviscon in',
#  'aluminum magnesium silicate': 'almasiliate',
#  'aluminum magnesium silicate hydroxide': 'inon ace in',
#  'aluminum sesquichlorohydrate': 'extra dry arrid',
#  'alumpotassium': 'k alum',
#  'alupent': 'metaproterenol',
#  'alupent inhalant': 'sulfate inhalation metaproterenol',
#  'alupram': 'diazepam',
#  'alustra': 'hydroquinone',
#  'alutab': 'hydroxide aluminum',
#  'aluzine': 'furosemide',
#  'alvesco': 'ciclesonide',
#  'alvesco mcgactuat': 'ciclesonide',
#  'amantadine': 'osmolex er',
#  'amantadine hydrochloride': 'symmetrel',
#  'amaranthus palmeri': 'weed careless',
#  'amaranthus palmeri retroflexus': 'weed careless redroot pigweed',
#  'amaranthus retroflexus': 'redroot pigweed',
#  'amaranthus retroflexus spinosus': 'redroot spiny pigweed',
#  'amaranthus spinosus': 'spiny pigweed',
#  'amaranthus tuberculatus': 'western waterhemp',
#  'amaryl': 'glimepiride',
#  'ambelcent': 'abelcet',
#  'ambenonium': 'mytelase',
#  'ambien': 'zolpidem',
#  'ambien cr': 'tartrate oral zolpidem',
#  'ambrosia acanthicarpa': 'ragweed false',
#  'ambrosia artemisiifolia': 'ragweed short',
#  'ambrosia artemisiifolia allergenic': 'ragweed short',
#  'ambrosia artemisiifolia gm': 'ragweed short',
#  'ambrosia artemisiifolia gm trifida per': 'giant western ragweed',
#  'ambrosia artemisiifolia trifida': 'giant western ragweed',
#  'ambrosia deltoidea': 'rabbit bush',
#  'ambrosia psilostachya': 'western ragweed',
#  'ambrosia psilostachya gm': 'western ragweed',
#  'ambrosia trifida': 'giant ragweed',
#  'ambrosia trifida gm per': 'giant ragweed',
#  'amcort': 'triamcinolone',
#  'amdinocillin': 'mecillinam',
#  'amdinocillin pivoxil': 'pivmecillinam',
#  'amen': 'medroxyprogesterone',
#  'amerge': 'naratriptan',
#  'americaine': 'benzocaine',
#  'americaine anesthetic lubricant': 'benzocaine',
#  'american': 'eastern',
#  'american basswood': 'tilia gm americana',
#  'american cockroach': 'blatta americana',
#  'american elm': 'ulmus gm americana',
#  'american elm siberian': 'pumila ulmus gm americana',
#  'american gm': 'eastern',
#  'american house dust mite': 'farinae dermatophagoides',
#  'american house dust mite european': 'pteronyssinus farinae dermatophagoides',
#  'american house dust mite extract european': 'odactra',
#  'americanan': 'americana',
#  'americet': 'acetaminophen caffeine butalbital',
#  'amerieanus': 'americanus',
#  'amevive': 'alefacept',
#  'amfetamine': 'amphetamine',
#  'amficot': 'ampicillin',
#  'amias': 'cilexetil candesartan',
#  'amicar': 'aminocaproic acid',
#  'amidate': 'etomidate',
#  'amidrine': 'isometheptene dichloralphenazone acetaminophen',
#  'amidrine apap': 'acetaminophen',
#  'amidronate': 'pamidronate',
#  'amifostine': 'ethyol',
#  'amigesic': 'salsalate',
#  'amikacin': 'amimax e',
#  'amikacin sulfate': 'amikin pediatric',
#  'amikin': 'amikacin',
#  'amilac': 'carbonate calcium',
#  'amilamont': 'amiloride',
#  'amiloride': 'amilamont',
#  'amiloride hydrochloride': 'midamor',
#  'amiloride hydrochloride hctz': 'moduretic',
#  'amiloride hydrochloride hydrochlorothiazide': 'moduretic',
#  'aminess': 'methionine lysine tryptophan histidine phenylalanine valine threonine isoleucine leucine',
#  'amino': 'butyl methyl dimethylaminoethyl',
#  'amino acids': 'cysteine valine serine phenylalanine sodium glycine histidine alanine methionine aspartate nacl leucine arginine taurine meq acetate proline metabisulfite tyrosine glutamate tryptophan lysine threonine isoleucine',
#  'amino acids with and electrolytes': 'tryptophan chloride sodium alanine nacl leucine meq acetate proline lysine cysteine valine phosphoric serine pot phenylalanine glycine histidine magnesium methionine calcium arginine threonine isoleucine acid',
#  'aminoacridine': 'aminacrine',
#  'aminobenzoate': 'potaba gm',
#  'aminobenzoic': 'paraaminobenzoic',
#  'aminobenzoic acid': 'potassium aminobenzoate',
#  'aminobenzoic acid arginine': 'swineaid',
#  'aminocaproic acid': 'gm amicar',
#  'aminocerv': 'cysteine methionine inositol sodium urea propionate',
#  'aminocerv cystine cervical': 'vaginal cysteine',
#  'aminodarone': 'amiodarone',
#  'aminoglutethimide': 'cytadren',
#  'aminolaevulinate': 'as aminolevulinate hydrochloride',
#  'aminolevulinate': 'levulan',
#  'aminolevulinic acid hydrochloride': 'ameluz',
#  'aminooptie': 'vitamin e',
#  'aminopentamide sulfate': 'centrine',
#  'aminophylline': 'truphylline',
#  'aminopyrine': 'aminophenazone',
#  'aminosalicylic': 'aminosalicylate',
#  'aminosalicylic acid': 'release delayed oral paser gm',
#  'aminosyn': 'cysteine threonine valine serine phenylalanine glycine histidine isoleucine alanine leucine arginine proline acid tryptophan lysine methionine phosphoric',
#  'aminosyn hbc': 'sulfitefree aminosynhbc',
#  'aminosyn ii': 'lysine glucose valine serine phenylalanine glycine histidine alanine methionine aspartate leucine nacetyltyrosine arginine proline glutamate tryptophan threonine isoleucine',
#  'aminosyn ii with dextrose': 'aspartate isoleucine threonine glucose valine serine proline phenylalanine tyrosine glutamate glycine histidine alanine tryptophan lysine methionine arginine leucine',
#  'aminosyn in ii dextrose': 'aspartate isoleucine threonine glucose valine serine proline phenylalanine tyrosine glutamate glycine histidine alanine tryptophan lysine methionine arginine leucine',
#  'aminosyn pf': 'sulfitefree aminosynpf',
#  'aminosyn sulfitefree': 'alanine lysine methionine tryptophan histidine glycine tyrosine phenylalanine proline serine valine threonine isoleucine arginine leucine',
#  'aminosynpf': 'lysine valine serine phenylalanine glycine histidine alanine methionine aspartate leucine arginine taurine proline tyrosine glutamate tryptophan threonine isoleucine',
#  'amiodarone': 'cordarone x',
#  'amiodarone hydrochloride': 'pacerone',
#  'amirax': 'hydroxyzine theophylline ephedrine',
#  'amisulpride': 'solian',
#  'amitone': 'carbonate calcium',
#  'amitriptyline': 'oral elavil',
#  'amitriptyline hydrochloride': 'vanatrip',
#  'amitriptyline hydrochloride chlordiazepoxide': 'limbitrol',
#  'amitriptyline hydrochloride perphenazine': 'triavil',
#  'amiurus': 'ameiurus',
#  'amiurus cattus': 'white catfish',
#  'amix': 'amoxicillin',
#  'ammoniaaromatic': 'spirit ammonia aromatic',
#  'ammoniac': 'ferula ammoniacum resin',
#  'ammonium': 'nhcl',
#  'ammonium chloride': 'uroeze',
#  'ammonium chloride enteric coated': 'oral release delayed nhcl',
#  'ammonium chloride per': 'nhcl',
#  'ammonium chloride potassium': 'nhcl pot',
#  'ammonium glycyrrhizate': 'glycyrrhizin ammoniated',
#  'ammonium lactate': 'lachydrin',
#  'ammonium lactate foam': 'kit mousse pro oz momexin cream gm',
#  'ammonium lactate pramoxine hydrochloride': 'ap aactin',
#  'ammonium lactate topical foam': 'kit momexin',
#  'ammonium lactate topical lotion': 'ultravate pac',
#  'ammonium lactate topical lotion halobetasol propionate': 'halonate pac',
#  'ammonium lactate topical lotion halobetasol propionate ointment pack': 'halonate pac',
#  'ammonium lactate urea': 'carbolac hp',
#  'amnest': 'isotretinoin',
#  'amnesteem': 'isotretinoin',
#  'amobarbital': 'amytal gm',
#  'amobarbital sodium': 'amytal',
#  'amodiaquine': 'camoquine',
#  'amopen': 'amoxicillin',
#  'amoram': 'amoxicillin',
#  'amorolfine': 'loceryl',
#  'amoxapine': 'asendin',
#  'amoxicillin': 'zoxycil',
#  'amoxicillin clavulanate': 'clavamox in',
#  'amoxicillin clavulanic acid': 'augmentin in',
#  'amoxicillin omeprazole rifabutin': 'talicia',
#  'amoxicillin oral': 'chewable amoxil',
#  'amoxicillin oral capsule clarithromycin tablet omeprazole delayed release pack': 'omeclamoxpak',
#  'amoxicillin oral capsule clarithromycin tablet omeprazole enteric coated pack': 'omeclamoxpak',
#  'amoxicot': 'amoxicillin',
#  'amoxidin': 'amoxicillin',
#  'amoxil': 'amoxicillin',
#  'amoxil fiztab': 'amoxicillin',
#  'amoxil pediatric drops': 'amoxicillin',
#  'amoxil per': 'amoxicillin',
#  'amoxil sf oral': 'chewable amoxicillin',
#  'amoxymed': 'amoxicillin',
#  'amphetamine': 'er adzenys',
#  'amphetamine aspartate sulfate dextroamphetamine saccharate': 'adderall xr',
#  'amphetamine dextroamphetamine': 'adderall',
#  'amphetamine sulfate': 'evekeo odt',
#  'amphetaminedextroamphetamine': 'aspartate sulfate saccharate oral amphetamine dextroamphetamine',
#  'amphojel': 'hydroxide aluminum',
#  'amphotericin b': 'fungizone',
#  'amphotericin b liposomal': 'abelcet in',
#  'ampicillin': 'vidopen',
#  'ampicillin sulbactam': 'unasyn gm',
#  'ampitrin': 'ampicillin',
#  'ampotericin in liposomal': 'complex amphotericin lipid',
#  'ampotericin liposomal': 'complex amphotericin lipid',
#  'ampotericin liposomal per': 'complex amphotericin lipid in',
#  'amprenavir': 'agenerase',
#  'amprolium': 'for poultry ampromedp',
#  'ampyra': 'oral hr dalfampridine',
#  'amrinone': 'v inocor i',
#  'amrit': 'amoxicillin',
#  'amrix': 'hydrochloride oral cyclobenzaprine',
#  'amsacrine': 'amsidine',
#  'amsidine': 'amsacrine',
#  'amturnide hemifumarate besylate hydrochlorothiazide': 'hctz',
#  'amtussin': 'hydrocodone chlorpheniramine pseudoephedrine',
#  'amvisc': 'sodium hyaluronate',
#  'amylase billion cells protease': 'amylases endopeptidases',
#  'amylase lipase protease': 'oral',
#  'amylase lipase protease enteric coated': 'oral release delayed',
#  'amylase lipase proteases': 'oral',
#  'amylase protease': 'amylases proteases',
#  'amylase protease delayed release': 'amylases endopeptidases',
#  'amylase protease enteric coated': 'release amylases delayed endopeptidases oral',
#  'amylase proteases': 'amylases oral endopeptidases',
#  'amylases': 'release delayed amylase',
#  'amylases atropine sendoisomer endopeptidases': 'protease hyoscyamine amylase',
#  'amylases cells endopeptidases': 'protease amylase',
#  'amylases endopeptidases': 'protease zypatt amylase',
#  'amylases endopeptidases enteric coated': 'release delayed protease ultresa oral amylase',
#  'amylases endopeptidases extended': 'protease delayed oral amylase',
#  'amylases endopeptidases lipase': 'zypatt',
#  'amylases endopeptidases lipase enteric coated': 'release delayed palipase mt oral',
#  'amylases enteric coated': 'release delayed oral amylase',
#  'amylases lipase protease': 'oral',
#  'amylases lipase protease enteric coated': 'release delayed oral',
#  'amylases lipase proteases': 'oral ec',
#  'amylases lipase proteases enteric coated': 'release delayed oral',
#  'amylases lipase proteinases enteric coated': 'oral release delayed',
#  'amylases proteases': 'oral amylase protease',
#  'amylases proteases enteric coated': 'release delayed oral amylase protease',
#  'amylases proteases lipase': 'plus',
#  'amylases proteases lipase enteric coated': 'oral release delayed',
#  'amylases proteases per gm': 'amylase protease',
#  'amylases proteinase': 'protease amylase',
#  'amylases proteinases': 'protease amylase',
#  'amylases proteinases enteric coated': 'release delayed protease oral amylase',
#  'amylases unt endopeptidases': 'creon',
#  'amylases unt endopeptidases enteric coated': 'oral release delayed creon',
#  'amylases unt endopeptidases lipase': 'zenpep',
#  'amylases unt endopeptidases lipase enteric coated': 'release delayed panocaps mt oral',
#  'amylases unt endopeptidases oral': 'coated enteric creon',
#  'amylases unt lipase protease': 'palpeon dr',
#  'amylases unt lipase protease enteric coated': 'oral release delayed creon',
#  'amylases unt lipase proteases': 'pancrelipase oral',
#  'amylases unt lipase proteases enteric coated': 'oral release delayed',
#  'amylases unt protease enteric coated': 'oral release delayed creon',
#  'amylases unt protease oral': 'coated enteric creon',
#  'amylases unt proteases': 'oral',
#  'amylases unt proteases enteric coated': 'oral release delayed',
#  'amytal': 'amobarbital',
#  'anabact': 'metronidazole',
#  'anabolin la': 'nandrolone',
#  'anacaine': 'benzocaine',
#  'anacin': 'aspirin caffeine',
#  'anacin adult low strength': 'aspirin',
#  'anacin af': 'acetaminophen',
#  'anacin maximum strength': 'acetaminophen',
#  'anadin allnight': 'oral asa',
#  'anadrol': 'oxymetholone',
#  'anaflex': 'polynoxylin',
#  'anafranil': 'clomipramine',
#  'anaguard': 'epinephrine',
#  'analog mixed injectable prefilled syringe': 'injector protamine pen in',
#  'analog mixed prefilled syringe': 'injector protamine pen in',
#  'analog mixed unt': 'protamine',
#  'analog mixed unt prefilled syringe': 'injector protamine pen in',
#  'analog prefilled syringe': 'injector pen in',
#  'analpram e gm prax wipe pack': 'hydrochloride acetate pramoxine hydrocortisone',
#  'analpram e gm with prax wipes pack': 'hydrochloride acetate pramoxine hydrocortisone',
#  'analpram e kit professional sample': 'rectal hydrochloride pramoxine hydrocortisone acetate cream',
#  'analpram e kit with prax medicated pad': 'rectal hydrochloride pramoxine hydrocortisone acetate cream',
#  'analpram e kit with prax medicated pads': 'rectal hydrochloride pramoxine hydrocortisone acetate cream',
#  'analpram e with prax wipes kit': 'hydrochloride acetate pramoxine hydrocortisone',
#  'analpram e x gm prax medicated wipes pack': 'hydrochloride acetate pramoxine hydrocortisone',
#  'analpram e x gm with prax wipes pack': 'hydrochloride acetate pramoxine hydrocortisone',
#  'analpram hc rectal': 'topical',
#  'analpramhc': 'pramoxine hydrocortisone',
#  'anamantle hc': 'hydrochloride acetate lidocaine hydrocortisone',
#  'ananase forte': 'bromelains',
#  'anaprox': 'naproxen',
#  'anas platyrhynchos': 'duck',
#  'anaspaz': 'sulfate oral hyoscyamine',
#  'anbesol': 'benzocaine',
#  'anbesol maximum strength': 'benzocaine',
#  'ancobon': 'flucytosine',
#  'and cold fastmelt': 'sinus oral',
#  'and cold fastmelt diphenhydramine hydrochloride citrate pseudoephedrine': 'sinus oral',
#  'and hibhepb': 'influenzae strain antigen ross capsular polysaccharide surface',
#  'and recombinant per': 'hm strain antigen unt surface',
#  'and varicella': 'okamerck wistar varicellazoster attenuated enders edmonston strain unt lynn ra jeryl',
#  'andro la': 'testosterone enanthate',
#  'androderm day': 'testosterone hr',
#  'androgel': 'testosterone',
#  'android': 'methyltestosterone',
#  'androloned': 'nandrolone',
#  'androstenedione': 'androstanedione',
#  'andryl': 'nandrolone',
#  'anectine': 'succinylcholine',
#  'anemone': 'pulsatilla',
#  'anemone whole': 'vulgaris',
#  'anestacaine': 'lidocaine',
#  'anestacon': 'lidocaine',
#  'anethaine': 'tetracaine',
#  ...}

# %% [markdown]
# 6. Finishing Touches
#
# We reason over the structure of the ontologies to normalize and to aggregate terms for further analysis<br>
# From the set of ontologies we use, the Annotator identifies all notes containing any string denoting this term as either its primary label or synonym.<br>
# We use __all other ontologies to normalize strings denoting rheumatoid arthritis or myocardial infarction__ and the Annotator identifies all notes containing them.<br>
# As an option, we can also enable reasoning to infer all subsumed terms, which increases the number of notes that we can identify beyond pure string matches.<br>
# For example, patients with Caplan’s or Felty’s syndrome may also fit the cohort of patients with rheumatoid arthritis.<br>
# Therefore, notes that mention these diseases can automatically be included as well even though their associated strings look nothing alike.<br>
# We did not use such reasoning for results reported in this specific study.
#
# __TO DO__:
# - Using the terms as features, we can define patterns of interest (such as patients with rheumatoid arthritis, who take rofecoxib, and then get myocardial infarctio), which we can use in data mining applications.# Deprecated

# %% [markdown]
# ### Additional info
#
# Steps:
# 1. Gather dataset
# 2. Preprocess using Open Biomedical Annotator
#     - Normalize records:
#         - if data type = :
#             - __diagnoses, medications, procedures, lab tests__: count presence of each normalized code in patient EHRs<br>
#                 → aiming to facilitate the modelling of related clinical events
#             - __free text clinical notes__: LePendu et al:
#                 - Allowed identifying the negated tags and those related to family history
#                     - A tag that appeared as negated in the note was considered not relevant and discarded <br>
#                       → Negated tags were identified using NegEx:
#                               a regular expression algorithm that implements several phrases indicating negation:
#                               - filters out sentences containing phrases that falsely appear to be negation phrases,
#                               - and limits the scope of the negation phrases
#                     - A tag that was related to family history was just flagged as such and differentiated from the directly patient-related tags.
#                     - We then analyzed similarities in the representation of temporally consecutive notes to remove duplicated information (e.g., notes recorded twice by mistake)
#
#                 - The parsed notes were further processed to reduce the sparseness of the representation (about 2 million normalized tags were extracted) and to obtain a semantic abstraction of the embedded clinical information.
#                     - To this aim we modeled the parsed notes using topic modeling <br>
#                         → an unsupervised inference process that captures patterns of word co-occurrences within documents to define topics and represent a document as a multinomial over these topics.<br>
#                              → Topic modeling has been applied to generalize clinical notes and improve automatic processing of patients data in several studies (e.g., see5,26–28). <br>
#                         → We used latent Dirichlet allocation as our implementation of topic modeling and we estimated the number of topics through perplexity analysis over one million random notes. <br>
#                         We found that 300 topics obtained the best mathematical generalization; therefore, each note was eventually summarized as a multinomial of 300 topic probabilities. <br>
#                         For each patient, we eventually retained one single topic-based representation averaged over all the notes available before the split-point.
